# %% [markdown]
# # Lab 8
#
# Dylan Liesenfelt

# %% [markdown]
# # Exercise 1:
# Obtain from Yahoo Finance historical data from a stock of your choosing. Use the option to download a .csv file.

# %%
file = r'COP3035/Labs/%Misc/SCHD.csv'

# %% [markdown]
# # Exercise 2:
#
# Implement a function to upload data from the .csv file storing in a list of dictionaries for each date using the
# following format for each line: See example:

# %%
file = r'../%Misc/SCHD.csv'

def readData(file):

    dataEntries = []

    with open(file) as file:
        headers = file.readline().strip().split(',')

        for line in file:
            lineData = line.strip().split(',')
            dataDict = {}

            for i in range(len(headers)):
                dataDict[headers[i]] = lineData[i]

            dataEntries.append(dataDict)

    return dataEntries

print(readData(file))
# Out:
# [{'Date': '2023-07-13', 'Open': '73.580002', 'High': '73.860001', 'Low': '73.510002', 'Close': '73.779999', 'Adj Close': '71.066345', 'Volume': '2998100'}, {'Date': '2023-07-14', 'Open': '73.720001', 'High': '73.750000', 'Low': '73.169998', 'Close': '73.379997', 'Adj Close': '70.681053', 'Volume': '3100000'}, {'Date': '2023-07-17', 'Open': '73.169998', 'High': '73.370003', 'Low': '72.940002', 'Close': '73.190002', 'Adj Close': '70.498039', 'Volume': '3325100'}, {'Date': '2023-07-18', 'Open': '73.120003', 'High': '74.110001', 'Low': '73.110001', 'Close': '73.779999', 'Adj Close': '71.066345', 'Volume': '3130100'}, {'Date': '2023-07-19', 'Open': '73.959999', 'High': '74.570000', 'Low': '73.959999', 'Close': '74.500000', 'Adj Close': '71.759857', 'Volume': '3351700'}, {'Date': '2023-07-20', 'Open': '74.440002', 'High': '74.940002', 'Low': '74.309998', 'Close': '74.800003', 'Adj Close': '72.048820', 'Volume': '2824000'}, {'Date': '2023-07-21', 'Open': '75.010002', 'High': '75.160004', 'Low': '74.779999', 'Close': '74.970001', 'Adj Close': '72.212578', 'Volume': '2626700'}, {'Date': '2023-07-24', 'Open': '75.080002', 'High': '75.570000', 'Low': '75.050003', 'Close': '75.410004', 'Adj Close': '72.636383', 'Volume': '2494000'}, {'Date': '2023-07-25', 'Open': '75.419998', 'High': '75.629997', 'Low': '75.250000', 'Close': '75.330002', 'Adj Close': '72.559334', 'Volume': '3777800'}, {'Date': '2023-07-26', 'Open': '75.029999', 'High': '75.699997', 'Low': '74.959999', 'Close': '75.470001', 'Adj Close': '72.694168', 'Volume': '2602000'}, {'Date': '2023-07-27', 'Open': '75.809998', 'High': '76.029999', 'Low': '75.070000', 'Close': '75.160004', 'Adj Close': '72.395576', 'Volume': '3481000'}, {'Date': '2023-07-28', 'Open': '75.589996', 'High': '75.870003', 'Low': '75.360001', 'Close': '75.629997', 'Adj Close': '72.848289', 'Volume': '2283100'}, {'Date': '2023-07-31', 'Open': '75.739998', 'High': '75.839996', 'Low': '75.389999', 'Close': '75.660004', 'Adj Close': '72.877197', 'Volume': '2559500'}, {'Date': '2023-08-01', 'Open': '75.570000', 'High': '75.690002', 'Low': '75.029999', 'Close': '75.320000', 'Adj Close': '72.549690', 'Volume': '3126800'}, {'Date': '2023-08-02', 'Open': '74.839996', 'High': '74.959999', 'Low': '74.419998', 'Close': '74.540001', 'Adj Close': '71.798386', 'Volume': '3566000'}, {'Date': '2023-08-03', 'Open': '74.330002', 'High': '74.720001', 'Low': '74.110001', 'Close': '74.459999', 'Adj Close': '71.721321', 'Volume': '2697800'}, {'Date': '2023-08-04', 'Open': '74.639999', 'High': '74.930000', 'Low': '74.059998', 'Close': '74.160004', 'Adj Close': '71.432365', 'Volume': '2754200'}, {'Date': '2023-08-07', 'Open': '74.370003', 'High': '74.870003', 'Low': '74.349998', 'Close': '74.809998', 'Adj Close': '72.058449', 'Volume': '2543200'}, {'Date': '2023-08-08', 'Open': '74.360001', 'High': '74.580002', 'Low': '73.820000', 'Close': '74.540001', 'Adj Close': '71.798386', 'Volume': '2433100'}, {'Date': '2023-08-09', 'Open': '74.519997', 'High': '74.790001', 'Low': '74.230003', 'Close': '74.349998', 'Adj Close': '71.615372', 'Volume': '1986700'}, {'Date': '2023-08-10', 'Open': '74.650002', 'High': '75.150002', 'Low': '74.199997', 'Close': '74.360001', 'Adj Close': '71.625008', 'Volume': '2348400'}, {'Date': '2023-08-11', 'Open': '74.230003', 'High': '74.650002', 'Low': '74.120003', 'Close': '74.570000', 'Adj Close': '71.827278', 'Volume': '1729600'}, {'Date': '2023-08-14', 'Open': '74.449997', 'High': '74.529999', 'Low': '74.199997', 'Close': '74.449997', 'Adj Close': '71.711685', 'Volume': '2206800'}, {'Date': '2023-08-15', 'Open': '74.029999', 'High': '74.029999', 'Low': '73.440002', 'Close': '73.570000', 'Adj Close': '70.864052', 'Volume': '2819100'}, {'Date': '2023-08-16', 'Open': '73.550003', 'High': '73.919998', 'Low': '73.209999', 'Close': '73.269997', 'Adj Close': '70.575089', 'Volume': '2430000'}, {'Date': '2023-08-17', 'Open': '73.599998', 'High': '73.980003', 'Low': '73.320000', 'Close': '73.379997', 'Adj Close': '70. ...

# %% [markdown]
# # Exercise 3:
# Implement a function that clean the data by converting string values to their appropriate numeric types.

# %%
data = readData(file)

def cleanData(data):

    for entry in data:

        for point in entry:

            if '2023-' not in entry[point] and '2024-' not in entry[point]:
                if type(entry[point]) != float:
                    entry[point] = float(entry[point])

    return data

print(cleanData(data))
# Out:
# [{'Date': '2023-07-13', 'Open': 73.580002, 'High': 73.860001, 'Low': 73.510002, 'Close': 73.779999, 'Adj Close': 71.066345, 'Volume': 2998100.0}, {'Date': '2023-07-14', 'Open': 73.720001, 'High': 73.75, 'Low': 73.169998, 'Close': 73.379997, 'Adj Close': 70.681053, 'Volume': 3100000.0}, {'Date': '2023-07-17', 'Open': 73.169998, 'High': 73.370003, 'Low': 72.940002, 'Close': 73.190002, 'Adj Close': 70.498039, 'Volume': 3325100.0}, {'Date': '2023-07-18', 'Open': 73.120003, 'High': 74.110001, 'Low': 73.110001, 'Close': 73.779999, 'Adj Close': 71.066345, 'Volume': 3130100.0}, {'Date': '2023-07-19', 'Open': 73.959999, 'High': 74.57, 'Low': 73.959999, 'Close': 74.5, 'Adj Close': 71.759857, 'Volume': 3351700.0}, {'Date': '2023-07-20', 'Open': 74.440002, 'High': 74.940002, 'Low': 74.309998, 'Close': 74.800003, 'Adj Close': 72.04882, 'Volume': 2824000.0}, {'Date': '2023-07-21', 'Open': 75.010002, 'High': 75.160004, 'Low': 74.779999, 'Close': 74.970001, 'Adj Close': 72.212578, 'Volume': 2626700.0}, {'Date': '2023-07-24', 'Open': 75.080002, 'High': 75.57, 'Low': 75.050003, 'Close': 75.410004, 'Adj Close': 72.636383, 'Volume': 2494000.0}, {'