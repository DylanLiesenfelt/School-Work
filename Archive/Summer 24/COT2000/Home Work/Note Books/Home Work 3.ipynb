# %% [markdown]
# Dylan Liesenfelt

# %% [markdown]
# # Question
# Rewrite the statements in if-then form.
#
# \begin{enumerate}
# \item[(a)] $ If the loop does not contain a stop or a go to, then it will repeat exactly N times $
#
# \item[(b)] $ If you do not freeze, then I’ll shoot $
#
# \item[(c)] $ If you do not fix my ceiling, then I won’t pay my rent $
# \end{enumerate}

# %% [markdown]
# # Question
# Construct truth tables for the statement forms.
#
# \begin{enumerate}
#
# \item[(a)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & \sim p & \sim q & \sim p \vee q & \sim p \vee q \rightarrow \sim q \\
# \hline
# T & T & F & F & T & F \\
# T & F & F & T & F & T \\
# F & T & T & F & T & F \\
# F & F & T & T & T & T \\
# \hline
# \end{array}
# $
#
# \item[(b)] $
# \begin{array}{|c|c|c|c|c|c|c|c|}
# \hline
# p & q & p \vee q & \sim p & \sim p \wedge q & (p \vee q) \vee (\sim p \wedge q) & (p \vee q) \vee (\sim p \wedge q) \rightarrow q \\
# \hline
# T & T & T & F & F & T & T \\
# T & F & T & F & F & T & F \\
# F & T & T & T & T & T & T \\
# F & F & F & T & F & F & T \\
# \hline
# \end{array} $
#
# \item[(c)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & r & p \rightarrow r & q \rightarrow r & (p \rightarrow r) \leftrightarrow (q \rightarrow r) \\
# \hline
# T & T & T & T & T & T \\
# T & T & F & F & F & T \\
# T & F & T & T & T & T \\
# T & F & F & F & T & F \\
# F & T & T & T & T & T \\
# F & T & F & T & F & F \\
# F & F & T & T & T & T \\
# F & F & F & T & T & T \\
# \hline
# \end{array} $
# \end{enumerate}

# %% [markdown]
# # Question
# Suppose that p and q are statements so that p → q is
# false. Find the truth values.
#
# \begin{enumerate}
# \item[(a)] $ True $
#
# \item[(b)] $ True $
#
# \item[(c)] $ True $
# \end{enumerate}

# %% [markdown]
# # Question
#
# \begin{enumerate}
# \item[(a)] $ \text(A.) \sim (p \land \sim q) \lor r \equiv (\sim p \lor q) \lor r \newline \text(B.) (\sim p \lor q) \lor r \equiv \sim (\sim (\sim p \lor q) \land \sim r) $
#
# \item[(b)] $ \text(A.) \sim (p \lor \sim q) \lor (r \lor q) \equiv (\sim p \land p) \lor (r \lor q) \newline \text(B.) (\sim p \land q) \lor ( r \lor q) \equiv \sim (\sim (\sim p \land q) \land \sim ( r \lor q))$
#
# \item[(c)] $  $
#
# \item[(d)] $  $
# \end{enumerate}

# %% [markdown]
# # Question
# Write negations, contrapositives, converse and in-verse for each of the following statements.
#
# \begin{enumerate}
# \item[(a)]
# Negation: P is a rectangle and P is not a square $\newline$
# Contrapositive: If P is not a square, then P is not a rectangle $\newline$
# Converse: If P is a square, then P is a rectangle $\newline$
# Inverse: If P is not a rectangle, then P is not a square $\newline$
#
# \item[(b)]
# Negation: Today is New Year’s Eve and tomorrow is February $\newline$
# Contrapositive: If tomorrow is February, then today is not New Year’s Eve $\newline$
# Converse: If tomorrow is not February, then today is New Year’s Eve $\newline$
# Inverse: If today is not New Year’s Eve, then tomorrow is February $\newline$
#
# \item[(c)]
# Negation: n is prime and n is not odd and n is not 2 $\newline$
# Contrapositive: If n is not odd and n is not 2, then n is not prime $\newline$
# Converse: If n is odd or n is 2, then n is prime $\newline$
# Inverse: If n is not prime, then n is not odd and n is not 2 $\newline$
#
# \item[(d)]
# Negation: Jane is Ann’s mother and Jim is not her uncle or Sue is not her aunt $\newline$
# Contrapositive: If Jim is not her uncle or Sue is not her aunt, then Jane is not Ann’s mother $\newline$
# Converse: If Jim is her uncle and Sue is her aunt, then Jane is Ann’s mother $\newline$
# Inverse: If Jane is not Ann’s mother, then Jim is not her uncle and Sue is not her aunt $\newline$
# \end{enumerate}

# %% [markdown]
# # Question
# Some of the arguments are valid, whereas others exhibit the converse or the inverse error. Use symbols to write the logical form of each argument. If the argument is valid, identify the rule of inference that guarantees its validity. Otherwise, state whether the converse or the inverse error is made.
#
# \begin{enumerate}
# \item[(a)]
# (Jules solved this problem correctly) = p  (Jules obtained the answer 2) = q $\newline$
# (A.) $p \rightarrow q \newline$
# (B.) $q \newline$
# (C.) $\therefore p \newline $
# Converse error
#
# \item[(b)]
# (I go to the movies) = p (I finish my homework) = q (I do well on the exam tomorrow) = r $\newline$
# (A.) $p \rightarrow \sim q \newline$
# (B.) $q \rightarrow \sim r \newline$
# (C.) $\therefore q \rightarrow \sim r \newline$
# Valid, Hypothetical Syllogism
#
# \item[(c)]
# (at least one of these two numbers is divisible by 6) = p (the product of these two numbers is divisible by 6) = q $\newline$
# (A.) $p \rightarrow q \newline$
# (B.) $\sim p \newline$
# (C.) $\therefore \sim q \newline$
# Inverse error
#
# \item[(d)]
# (This computer program is correct) = p  (it produces the correct output when run with the test data my teacher gave me) = q $\newline$
# (A.) $p \rightarrow q \newline$
# (B.) $q \newline$
# (C.) $\therefore p$
# Converse error $\newline$
#
# \item[(e)]
# (Sandra knows Java) = p (Sandra knows C++) = q $\newline$
# (A.) $p \land q \newline$
# (B.) $\therefore p \newline$
# Valid, Simplification $\newline$
# \end{enumerate}

# %% [markdown]
# # Question
# Explain in your own words what distinguishes a valid form of argument from an invalid one. In addition what make an argument a sound argument. $\newline$
# $\newline$ Validity is dependent on the premise and the conclusion of the argument if the follow rules of logic.

# %% [markdown]
# # Question
# Use truth tables to determine whether the argument forms are valid. Indicate which columns represent the premises and which represent the conclusion, and include a sentence explaining how the truth table supports your answer. Your explanation should show that you understand what it means for a form of argument to be valid or invalid.
#
# \begin{enumerate}
# \item[(a)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & p \rightarrow q & q \rightarrow p & p \lor q & \text{Premises lead to conclusion} \\
# \hline
# T & T & T & T & T & T \\
# T & F & F & T & T & F \\
# F & T & T & F & T & F \\
# F & F & T & T & F & T \\
# \hline
# \end{array} $
# $\newline$ This argument form is $\textbf{invalid}$ because the premises $(p \rightarrow q)$ and $(q \rightarrow p)$ do not always lead to the conclusion $(p \lor q)$. The rows where the conclusion is false while the premises are true show the invalidity.
#
# \item[(b)] $
# \begin{array}{|c|c|c|c|c|c|c|}
# \hline
# p & q & p \lor q & p \rightarrow \neg q & p \rightarrow r & r & \text{Premises lead to conclusion} \\
# \hline
# T & T & T & F & T & T & F \\
# T & F & T & T & T & T & T \\
# F & T & T & T & T & T & T \\
# F & F & F & T & T & T & T \\
# \hline
# \end{array}$
# $\newline$ This argument is $\textbf{invalid}$ because there is a case where the premises are all true but the conclusion is false (first row).
#
# \item[(c)] $
# \begin{array}{|c|c|c|c|c|c|c|c|}
# \hline
# p & q & \neg r & (p \land q) & (p \land q) \rightarrow \neg r & p \lor \neg q & \neg q \rightarrow p & \text{Premises lead to conclusion} \\
# \hline
# T & T & T & T & T & T & T & T \\
# T & T & F & T & F & T & T & F \\
# T & F & T & F & T & T & T & T \\
# T & F & F & F & T & T & T & T \\
# F & T & T & F & T & F & F & T \\
# F & T & F & F & T & F & F & T \\
# F & F & T & F & T & T & T & T \\
# F & F & F & F & T & T & T & T \\
# \hline
# \end{array} $
# $\newline$ This argument form is $\textbf{invalid}$ because there is a case where the premises are all true but the conclusion is false (second row).
#
# \item[(d)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & r & p \rightarrow r & q \rightarrow r & (p \lor q) \rightarrow r \\
# \hline
# T & T & T & T & T & T \\
# T & T & F & F & F & F \\
# T & F & T & T & T & T \\
# T & F & F & F & T & F \\
# F & T & T & T & T & T \\
# F & T & F & T & F & F \\
# F & F & T & T & T & T \\
# F & F & F & T & T & T \\
# \hline
# \end{array} $
# $\newline$ This argument form is $\textbf{valid}$ because in all cases where the premises are true, the conclusion is also true.
# \end{enumerate}

# %% [markdown]
# # Question
