# %% [markdown]
# Dylan Liesenfelt

# %% [markdown]
# # Question
# Write the following statements in symbolic form using the symbols $\sim$, $\land$, and $\lor$ and the indicated letters to represent component
# statements.
#
# \begin{enumerate}
# \item[(a)] $ h \land w \land \sim s $
#
# \item[(b)] $ \sim w \land h \land s $
#
# \item[(c)] $ \sim h \land \sim w \land \sim s $
#
# \item[(d)] $ \sim w \land \sim s \land h $
#
# \item[(e)] $ w \land \sim h \land \sim s $
# \end{enumerate}

# %% [markdown]
# # Question
#
# \begin{enumerate}
# \item[(a)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & p \land q & \sim (p \land q) & p \lor q & \sim (p \land q) \lor (p \lor q) \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{F} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{T} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{F} & \text{F} & \text{T} & \text{F} & \text{T} \\
# \hline
# \end{array} $
#
# \item[(b)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & r & \sim q & \sim q \lor r & p \land (\sim q \lor r) \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{F} & \text{T} & \text{T} \\
# \text{T} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{T} & \text{F} & \text{T} & \text{T} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{T} & \text{T} & \text{F} & \text{T} & \text{F} \\
# \text{F} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{F} & \text{T} & \text{T} & \text{T} & \text{F} \\
# \text{F} & \text{F} & \text{F} & \text{T} & \text{T} & \text{F} \\
# \hline
# \end{array} $
# \end{enumerate}

# %% [markdown]
# # Question
# Determine whether the statement forms are logically equivalent.
# In each case, construct a truth table and include a sentence
# justifying your answer. Your sentence should show that you
# understand the meaning of logical equivalence.
#
# \begin{enumerate}
# \item[(a)] $
# \begin{array}{|c|c|c|c|c|}
# \hline
# p & q & p \land q & p \lor (p \land q) & q \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{F} \\
# \text{F} & \text{T} & \text{F} & \text{F} & \text{T} \\
# \text{F} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \hline
# \end{array}$
#
# The columns for $p \lor (p \land q)$ and q are not the same, so they can not be logically equivalent
#
# \item[(b)] $
# \begin{array}{|c|c|c|c|c|c|c|}
# \hline
# p & q & p \land q & \sim (p \land q) & \sim p & \sim q & \sim p \land \sim q \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{F} & \text{T} & \text{F} \\
# \text{F} & \text{T} & \text{F} & \text{T} & \text{T} & \text{F} & \text{F} \\
# \text{F} & \text{F} & \text{F} & \text{T} & \text{T} & \text{T} & \text{T} \\
# \hline
# \end{array}$
#
# The columns for $\sim (p \land q)$ and $\sim p \land \sim q$ are not the same, so they can not be logically equivalent
#
# \item[(c)] $
# \begin{array}{|c|c|c|c|c|c|c|c|}
# \hline
# p & q & r & q \lor r & p \land (q \lor r) & p \land q & p \land r & (p \land q) \lor (p \land r) \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{T} & \text{T} & \text{T} & \text{T} & \text{T} \\
# \text{T} & \text{T} & \text{F} & \text{T} & \text{T} & \text{T} & \text{F} & \text{T} \\
# \text{T} & \text{F} & \text{T} & \text{T} & \text{T} & \text{F} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{T} & \text{T} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{T} & \text{F} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{F} & \text{T} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \hline
# \end{array} $
#
# The columns for $p \land (q \lor r)$ and $(p \land q) \lor (p \land r) $ are no the same, so they are logically equivalent
# \end{enumerate}

# %% [markdown]
# # Question
# Assume x is a particular real number and use De Morgan’s laws
# to write negations for the statements
#
# \begin{enumerate}
# \item[(a)] $ x \leq -2 \text{ or } x \geq 6 $
#
# \item[(b)] $ x \leq -9 \text{ or } x \geq 2 $
#
# \item[(c)] $ x \geq 2 \text{ and } x \leq 6 $
#
# \item[(d)] $ x > -1 \text{ and } x \leq 1 $
#
# \item[(e)] $ x \geq 0 \text{ or } x < -4 $
# \end{enumerate}

# %% [markdown]
# # Question
# Use truth tables to establish which of the statement forms are
# tautologies and which are contradictions.
#
# \begin{enumerate}
# \item[(a)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & p \land q & \sim (p \land q) & p \lor q & \sim (p \land q) \lor (p \lor q) \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{F} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{T} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{F} & \text{F} & \text{T} & \text{F} & \text{T} \\
# \hline
# \end{array} $
#
# \item[(b)] $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# p & q & r & \sim q & \sim q \lor r & p \land (\sim q \lor r) \\
# \hline
# \text{T} & \text{T} & \text{T} & \text{F} & \text{T} & \text{T} \\
# \text{T} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{T} & \text{F} & \text{T} & \text{T} & \text{T} & \text{T} \\
# \text{T} & \text{F} & \text{F} & \text{T} & \text{T} & \text{T} \\
# \text{F} & \text{T} & \text{T} & \text{F} & \text{T} & \text{F} \\
# \text{F} & \text{T} & \text{F} & \text{F} & \text{F} & \text{F} \\
# \text{F} & \text{F} & \text{T} & \text{T} & \text{T} & \text{F} \\
# \text{F} & \text{F} & \text{F} & \text{T} & \text{T} & \text{F} \\
# \hline
# \end{array} $
# \end{enumerate}

# %% [markdown]
# # Question
# Determine whether the statement forms are logically equivalent.
# In each case, construct a truth table and include a sentence
# justifying your answer. Your sentence should show that you
# understand the meaning of logical equivalence.
#
#
# \begin{enumerate}
#     \item[(a)]
#     \[
#     \begin{array}{|c|c|c|c|c|c|c|c|}
#     \hline
#     p & q & p \land q & \neg p & \neg q & p \land \neg q & \neg p \lor (p \land \neg q) & (p \land q) \lor (\neg p \lor (p \land \neg q)) \\
#     \hline
#     T & T & T & F & F & F & F & T \\
#     T & F & F & F & T & T & T & T \\
#     F & T & F & T & F & F & T & T \\
#     F & F & F & T & T & F & T & T \\
#     \hline
#     \end{array}
#     \]
#
#     \text{ This is a tautology}
#
#
#     \item[(b)]
#     \[
#     \begin{array}{|c|c|c|c|c|c|c|}
#     \hline
#     p & q & \neg p & \neg q & p \land \neg q & \neg p \lor q & (p \land \neg q) \land (\neg p \lor q) \\
#     \hline
#     T & T & F & F & F & T & F \\
#     T & F & F & T & T & F & F \\
#     F & T & T & F & F & T & F \\
#     F & F & T & T & F & T & F \\
#     \hline
#     \end{array}
#     \]
#
#     \text{ This is a contradiction}
#
#     \item[(c)]
#     \[
#     \begin{array}{|c|c|c|c|c|c|c|c|c|}
#     \hline
#     p & q & r & \neg p & \neg q & \neg p \land q & q \land r & (\neg p \land q) \land (q \land r) & ((\neg p \land q) \land (q \land r)) \lor \neg q \\
#     \hline
#     T & T & T & F & F & F & T & F & F \\
#     T & T & F & F & F & F & F & F & F \\
#     T & F & T & F & T & F & F & F & T \\
#     T & F & F & F & T & F & F & F & T \\
#     F & T & T & T & F & T & T & T & T \\
#     F & T & F & T & F & T & F & F & F \\
#     F & F & T & T & T & F & F & F & T \\
#     F & F & F & T & T & F & F & F & T \\
#     \hline
#     \end{array}
#     \]
#
#     \text{ This is a neither}
#
# \end{enumerate}

# %% [markdown]
# # Question
# Using Exclusive OR
#
# Is \((p \oplus q) \oplus r \equiv p \oplus (q \oplus r)\)? Justify your answer.
#
# They are logically equal. They both evaluate to true if either only one of \(p\), \(q\), or \(r\) is true, but not more than one. But, also they both evaluate to false if all three are true or all three are false.

# %% [markdown]
# # Question
# What logical equivalence is used for each step?
#
# \begin{enumerate}
#     \item[(a)] Distributive
#     \item[(b)] Commutative Law
#     \item[(c)] Negation Law
#     \item[(d)] Identity Law
# \end{enumerate}

# %% [markdown]
# # Question
# Verify the logical equivalences. Supply a reason for each step.
#
# \((p \land \neg q) \lor p \equiv p\)
#
# \begin{enumerate}
#     \item[(a)] \text{Distributive: } \((p \land \neg q) \lor p \equiv (p \lor p) \land (p \lor \neg q)\) \\
#     Distributing \(p\) across the OR operation.
#
#     \item[(b)] \text{Idempotent Law: } \((p \lor p) \equiv p\) \\
#     Any proposition OR-ed with itself is logically equivalent to itself.
#
#     \item[(c)] \text{Absorption Law: } \((p \lor \neg q) \land (p \lor q) \equiv p\) \\
#     Whenever \(p\) is true, the whole expression evaluates to true.
# \end{enumerate}
#
# Yes, \((p \land \neg q) \lor p \equiv p\).
